# %% [markdown]
# # Create Ruta count

# %%
import pandas as pd
from funtions import *

# %%
df = pd.read_csv("./Dataset/5.df_clean.csv")

# %%
df.columns
# Out:
# Index(['Semana', 'Agencia_ID', 'Canal_ID', 'Ruta_SAK', 'Cliente_ID',
#        'Producto_ID', 'Venta_uni_hoy', 'Venta_hoy', 'Dev_uni_proxima',
#        'Dev_proxima', 'Demanda_uni_equil', 'Town', 'State', 'Address',
#        'Latitude', 'Longitude', 'NombreCliente', 'NombreProducto', 'desc', 'g',
#        'brand'],
#       dtype='object')

# %%
#test = df.assign(number = lambda x :(x['Ruta_SAK']))

# %%
num_rotas = df.Ruta_SAK.value_counts()

# %%
num_rotas
# Out:
# 1201    6021
# 1203    5882
# 1204    5553
# 1202    5501
# 1205    5336
#         ...
# 4072       1
# 3967       1
# 9829       1
# 7037       1
# 9839       1
# Name: Ruta_SAK, Length: 2264, dtype: int64

# %%
df_ = df['Ruta_SAK'].value_counts().rename_axis('Ruta_SAK').reset_index(name='Ruta_SAK_counts')

# %%
df_
# Out:
#       Ruta_SAK  Ruta_SAK_counts
# 0         1201             6021
# 1         1203             5882
# 2         1204             5553
# 3         1202             5501
# 4         1205             5336
# ...        ...              ...
# 2259      4072                1
# 2260      3967                1
# 2261      9829                1
# 2262      7037                1
# 2263      9839                1
#
# [2264 rows x 2 columns]

# %%
df = pd.merge(df, df_, on='Ruta_SAK', how='inner')

# %%
df.head()
# Out:
#    Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 0       5        1936         1      1158     1575677         2425
# 1       8        1936         1      1158      841050         2425
# 2       6        1936         1      1158     3422113         2425
# 3       7        1936         1      1158     1570783         2425
# 4       9        1936         1      1158     2296923         2425
#
#    Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  Dev_proxima  ...       State  \
# 0             60      270.0                0          0.0  ...  GUANAJUATO
# 1             20       90.0                0          0.0  ...  GUANAJUATO
# 2             10       45.0                0          0.0  ...  GUANAJUATO
# 3             25      112.5                0          0.0  ...  GUANAJUATO
# 4             23      103.5                0          0.0  ...  GUANAJUATO
#
#                           Address   Latitude  Longitude    NombreCliente  \
# ...

# %%
resumetable(df)
# Out:
# Dataset Shape: (964348, 22)
#                  Name   dtypes  Missing  Uniques  \
# 0              Semana    int64        0        7
# 1          Agencia_ID    int64        0      551
# 2            Canal_ID    int64        0        9
# 3            Ruta_SAK    int64        0     2264
# 4          Cliente_ID    int64        0   450788
# 5         Producto_ID    int64        0     1308
# 6       Venta_uni_hoy    int64        0      614
# 7           Venta_hoy  float64        0    13671
# 8     Dev_uni_proxima    int64        0      134
# 9         Dev_proxima  float64        0     2515
# 10  Demanda_uni_equil    int64        0      613
# 11               Town   object        0      256
# 12              State   object        0       33
# 13            Address   object        0      257
# 14           Latitude  float64        0      257
# 15          Longitude  float64        0      257
# 16      NombreCliente   object        0       18
# ...

# %%
dropColumns = ["Agencia_ID", "Canal_ID", "Ruta_SAK", "Cliente_ID", "Producto_ID", "Town", "State", "Address", "NombreProducto"]

df.drop(dropColumns, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Semana', 'Venta_uni_hoy', 'Venta_hoy', 'Dev_uni_proxima',
#        'Dev_proxima', 'Demanda_uni_equil', 'Latitude', 'Longitude',
#        'NombreCliente', 'desc', 'g', 'brand', 'Ruta_SAK_counts'],
#       dtype='object')

# %%
renameColumns = {"Semana":"Week", 
                 "Venta_uni_hoy":"SalesUnitWeek",
                 "Venta_hoy": "SalesPesosWeek",
                 "Dev_proxima": "RetrunsPesosNestWeek",
                 "Dev_uni_proxima": "ReturnsUnitNextWeek",
                 "SalesUnitWeek": "ReturnsPesosNextWeek",
                 "Demanda_uni_equil": "AjustedDemand",
                 "NombreCliente": "typeClient"
                 }
df.rename(columns=renameColumns, inplace=True)

# %%
df.columns
# Out:
# Index(['Week', 'SalesUnitWeek', 'SalesPesosWeek', 'ReturnsUnitNextWeek',
#        'RetrunsPesosNestWeek', 'AjustedDemand', 'Latitude', 'Longitude',
#        'typeClient', 'desc', 'g', 'brand', 'Ruta_SAK_counts'],
#       dtype='object')

# %%
df.to_csv("./Dataset/5.1.df_clean_droped.csv", index=False)
