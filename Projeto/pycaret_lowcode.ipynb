# %%
# !pip install --pre pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycaret
#   Downloading pycaret-3.0.0rc4-py3-none-any.whl (487 kB)
#      |████████████████████████████████| 487 kB 40.9 MB/s
# Collecting lightgbm>=3.0.0
#   Downloading lightgbm-3.3.3-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 50.0 MB/s
# Requirement already satisfied: scipy<1.9.0 in /usr/local/lib/python3.7/dist-packages (from pycaret) (1.7.3)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from pycaret) (0.8.1)
# Collecting scikit-plot>=0.3.7
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: pandas<1.5.0,>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pycaret) (1.3.5)
# Requirement already satisfied: markupsafe>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from pycaret) (2.0.1)
# Requirement already satisfied: joblib>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from pycaret) (1.2.0)
# Collecting category-encoders>=2.4.0
#   Downloading category_encoders-2.5.1.post0-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 988 kB/s
# Requirement already satisfied: importlib-metadata>=4.12.0 in /usr/local/lib/python3.7/dist-packages (from pycaret) (4.13.0)
# Collecting kaleido>=0.2.1
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      |████████████████████████████████| 79.9 MB 1.2 MB/s
# Collecting pyod>=0.9.8
#   Downloading pyod-1.0.5.tar.gz (137 kB)
#      |████████████████████████████████| 137 kB 71.7 MB/s
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pycaret) (5.5.0)
# Collecting requests>=2.27.1
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.6 MB/s
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.7/dist-packages (from pycaret) (7.9.0)
# Requirement already satisfied: yellowbrick>=1.4 in /usr/local/lib/python3.7/dist-packages (from pycaret) (1.5)
# Collecting sktime~=0.13.2
#   Downloading sktime-0.13.4-py3-none-any.whl (7.0 MB)
#      |████████████████████████████████| 7.0 MB 60.1 MB/s
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.7/dist-packages (from pycaret) (0.12.2)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.7/dist-packages (from pycaret) (1.0.2)
# Collecting psutil>=5.9.0
#   Downloading psutil-5.9.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (291 kB)
#      |████████████████████████████████| 291 kB 77.6 MB/s
# Collecting plotly-resampler>=0.7.2.2
#   Downloading plotly-resampler-0.8.2rc3.tar.gz (94 kB)
#      |████████████████████████████████| 94 kB 3.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   WARNING: Requested plotly-resampler>=0.7.2.2 from https://files.pythonhosted.org/packages/76/08/955275e3b400527494ed9cbfe9fd8887b50470ad13b8ae81de50796cf5ab/plotly-resampler-0.8.2rc3.tar.gz#sha256=26490530069f89491bafd4428c1d08393ac026a70ea3173fd954c45f739cb6dc (from pycaret), but installing version 0.8.2rc3
# Requirement already satisfied: numpy<1.23,>=1.21 in /usr/local/lib/python3.7/dist-packages (from pycaret) (1.21.6)
# Collecting numba~=0.55.0
#   Downloading numba-0.55.2-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 60.9 MB/s
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.7/dist-packages (from pycaret) (4.64.1)
# Requirement already satisfied: jinja2>=1.2 in /usr/local/lib/python3.7/dist-packages (from pycaret) (2.11.3)
# Collecting pmdarima!=1.8.1,<2.0.0,>=1.8.0
#   Downloading pmdarima-1.8.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 52.9 MB/s
# Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.7/dist-packages (from pycaret) (7.7.1)
# Collecting schemdraw>=0.14
#   Downloading schemdraw-0.15-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 59.1 MB/s
# Collecting tbats>=1.1.0
#   Downloading tbats-1.1.1-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 2.5 MB/s
# Collecting matplotlib>=3.3.0
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 59.1 MB/s
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.12.0->pycaret) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.12.0->pycaret) (4.1.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret) (57.4.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 88.2 MB/s
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret) (2.0.10)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.6.5->pycaret) (3.6.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.6.5->pycaret) (5.3.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.6.5->pycaret) (3.0.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm>=3.0.0->pycaret) (0.37.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->pycaret) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->pycaret) (1.4.4)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 62.5 MB/s
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->pycaret) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Collecting llvmlite<0.39,>=0.38.0rc1
#   Downloading llvmlite-0.38.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      |████████████████████████████████| 34.5 MB 1.3 MB/s
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<1.5.0,>=1.3.0->pycaret) (2022.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=5.0.0->pycaret) (8.1.0)
# Collecting trace-updater>=0.0.8
#   Downloading trace_updater-0.0.8-py3-none-any.whl (185 kB)
#      |████████████████████████████████| 185 kB 70.6 MB/s
# Collecting dash<3.0.0,>=2.2.0
#   Downloading dash-2.6.2-py3-none-any.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 69.2 MB/s
# Collecting Flask-Cors<4.0.0,>=3.0.10
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting jupyter-dash>=0.4.2
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Collecting orjson<4.0.0,>=3.7.7
#   Downloading orjson-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (270 kB)
#      |████████████████████████████████| 270 kB 76.4 MB/s
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: Flask>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (1.1.4)
# Collecting flask-compress
#   Downloading Flask_Compress-1.13-py3-none-any.whl (7.9 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (1.0.1)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (7.1.2)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (1.1.0)
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Collecting retrying
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima!=1.8.1,<2.0.0,>=1.8.0->pycaret) (0.29.32)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima!=1.8.1,<2.0.0,>=1.8.0->pycaret) (1.24.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.27.1->pycaret) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.27.1->pycaret) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.27.1->pycaret) (2.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0->pycaret) (3.1.0)
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.13->sktime~=0.13.2->pycaret) (1.14.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (5.5.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (5.7.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.13.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (23.2.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (5.6.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.7.0)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp37-cp37m-manylinux1_x86_64.whl (357 kB)
#      |████████████████████████████████| 357 kB 55.5 MB/s
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (5.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.3.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (5.10.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (22.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Building wheels for collected packages: plotly-resampler, pyod, retrying
#   Building wheel for plotly-resampler (PEP 517) ... done
#   Created wheel for plotly-resampler: filename=plotly_resampler-0.8.2rc3-cp37-cp37m-manylinux_2_27_x86_64.whl size=120163 sha256=ed1950f33f9774ce958d95900bebcccdb33eadf24ca154fd25c79783f1fb7dbd
#   Stored in directory: /root/.cache/pip/wheels/9e/80/91/248dbb37072f642b76023e597852c40e531a8040dd178613c5
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-1.0.5-py3-none-any.whl size=170258 sha256=bab5638386696b3ec6977854e74edec58eec8da1c390316110f9119faae68738
#   Stored in directory: /root/.cache/pip/wheels/29/98/25/bc9bfccf3907de246c61668bc09c39216ec157f8218aea4c16
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11447 sha256=7cf7b4c2b324a660c40b804de122f8f757c16477347540f5d0ae76c9f646e910
#   Stored in directory: /root/.cache/pip/wheels/f9/8d/8d/f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
# Successfully built plotly-resampler pyod retrying
# Installing collected packages: jedi, brotli, flask-compress, dash-table, dash-html-components, dash-core-components, retrying, requests, nest-asyncio, llvmlite, fonttools, dash, ansi2html, trace-updater, pmdarima, orjson, numba, matplotlib, jupyter-dash, Flask-Cors, deprecated, tbats, sktime, scikit-plot, schemdraw, pyod, psutil, plotly-resampler, lightgbm, kaleido, category-encoders, pycaret
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.39.1
#     Uninstalling llvmlite-0.39.1:
#       Successfully uninstalled llvmlite-0.39.1
#   Attempting uninstall: numba
#     Found existing installation: numba 0.56.3
#     Uninstalling numba-0.56.3:
#       Successfully uninstalled numba-0.56.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
# Successfully installed Flask-Cors-3.0.10 ansi2html-1.8.0 brotli-1.0.9 category-encoders-2.5.1.post0 dash-2.6.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 deprecated-1.2.13 flask-compress-1.13 fonttools-4.38.0 jedi-0.18.1 jupyter-dash-0.4.2 kaleido-0.2.1 lightgbm-3.3.3 llvmlite-0.38.1 matplotlib-3.5.3 nest-asyncio-1.5.6 numba-0.55.2 orjson-3.8.0 plotly-resampler-0.8.2rc3 pmdarima-1.8.5 psutil-5.9.3 pycaret-3.0.0rc4 pyod-1.0.5 requests-2.28.1 retrying-1.3.3 schemdraw-0.15 scikit-plot-0.3.7 sktime-0.13.4 tbats-1.1.1 trace-updater-0.0.8

# %%
import pandas as pd
df = pd.read_csv('./Dataset/5.2.df_clean_target.csv')

# %%
df.target.isnull().sum()
# Out:
# 0

# %%
from pycaret.classification import *
s = setup(df, target = 'target')
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            19:31:19
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#                        Data Type
# Week                 Categorical
# SalesUnitWeek            Numeric
# SalesPesosWeek           Numeric
# ReturnsUnitNextWeek      Numeric
# ReturnPesosNextWeek      Numeric
# Latitude                 Numeric
# Longitude                Numeric
# typeClient           Categorical
# desc                 Categorical
# g                        Numeric
# brand                Categorical
# Ruta_SAK_counts          Numeric
# target                     Label

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_e9371_ th {
#   text-align: left;
# }
# #T_e9371_row0_col0, #T_e9371_row0_col1, #T_e9371_row0_col5, #T_e9371_row0_col6, #T_e9371_row1_col0, #T_e9371_row1_col1, #T_e9371_row1_col5, #T_e9371_row1_col6, #T_e9371_row2_col0, #T_e9371_row2_col1, #T_e9371_row2_col5, #T_e9371_row2_col6, #T_e9371_row3_col0, #T_e9371_row3_col1, #T_e9371_row3_col5, #T_e9371_row3_col6, #T_e9371_row4_col0, #T_e9371_row4_col1, #T_e9371_row4_col2, #T_e9371_row4_col3, #T_e9371_row4_col4, #T_e9371_row4_col5, #T_e9371_row4_col6, #T_e9371_row5_col0, #T_e9371_row5_col1, #T_e9371_row5_col2, #T_e9371_row5_col3, #T_e9371_row5_col4, #T_e9371_row5_col5, #T_e9371_row5_col6, #T_e9371_row6_col0, #T_e9371_row6_col1, #T_e9371_row6_col2, #T_e9371_row6_col3, #T_e9371_row6_col4, #T_e9371_row6_col5, #T_e9371_row6_col6, #T_e9371_row7_col0, #T_e9371_row7_col1, #T_e9371_row7_col2, #T_e9371_row7_col3, #T_e9371_row7_col4, #T_e9371_row7_col5, #T_e9371_row7_col6, #T_e9371_row8_col0, #T_e9371_row8_col1, #T_e9371_row8_col2, #T_e9371_row8_col3, #T_e9371_row8_col4, #T_e9371_row8_col5, #T_e9371_row8_col6, #T_e9371_row9_col0, #T_e9371_row9_col2, #T_e9371_row9_col3, #T_e9371_row9_col4, #T_e9371_row9_col5, #T_e9371_row9_col6, #T_e9371_row10_col0, #T_e9371_row10_col1, #T_e9371_row10_col2, #T_e9371_row10_col3, #T_e9371_row10_col4, #T_e9371_row10_col5, #T_e9371_row10_col6, #T_e9371_row11_col0, #T_e9371_row11_col1, #T_e9371_row11_col2, #T_e9371_row11_col3, #T_e9371_row11_col4, #T_e9371_row11_col5, #T_e9371_row11_col6, #T_e9371_row12_col0, #T_e9371_row12_col1, #T_e9371_row12_col2, #T_e9371_row12_col3, #T_e9371_row12_col4, #T_e9371_row13_col0, #T_e9371_row13_col1, #T_e9371_row13_col2, #T_e9371_row13_col3, #T_e9371_row13_col4, #T_e9371_row13_col5, #T_e9371_row13_col6, #T_e9371_row14_col0, #T_e9371_row14_col1, #T_e9371_row14_col2, #T_e9371_row14_col3, #T_e9371_row14_col4, #T_e9371_row14_col5, #T_e9371_row14_col6, #T_e9371_row15_col0, #T_e9371_row15_col1, #T_e9371_row15_col2, #T_e9371_row15_col3, #T_e9371_row15_col4, #T_e9371_row15_col5, #T_e9371_row15_col6, #T_e9371_row16_col0, #T_e9371_row16_col1, #T_e9371_row16_col2, #T_e9371_row16_col3, #T_e9371_row16_col4, #T_e9371_row16_col5, #T_e9371_row16_col6, #T_e9371_row17_col0, #T_e9371_row17_col1, #T_e9371_row17_col2, #T_e9371_row17_col3, #T_e9371_row17_col4, #T_e9371_row17_col5, #T_e9371_row17_col6 {
#   text-align: left;
# }
# #T_e9371_row0_col2, #T_e9371_row0_col3, #T_e9371_row0_col4, #T_e9371_row1_col2, #T_e9371_row1_col3, #T_e9371_row1_col4, #T_e9371_row2_col2, #T_e9371_row2_col3, #T_e9371_row2_col4, #T_e9371_row3_col2, #T_e9371_row3_col3, #T_e9371_row3_col4, #T_e9371_row9_col1, #T_e9371_row12_col5, #T_e9371_row12_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e9371_row0_col7, #T_e9371_row1_col7, #T_e9371_row2_col7, #T_e9371_row3_col7, #T_e9371_row4_col7, #T_e9371_row5_col7, #T_e9371_row6_col7, #T_e9371_row7_col7, #T_e9371_row8_col7, #T_e9371_row9_col7, #T_e9371_row10_col7, #T_e9371_row11_col7, #T_e9371_row12_col7, #T_e9371_row13_col7, #T_e9371_row14_col7, #T_e9371_row15_col7, #T_e9371_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e9371_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e9371_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9371_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_e9371_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_e9371_row0_col1" class="data row0 col1" >0.0648</td>
#       <td id="T_e9371_row0_col2" class="data row0 col2" >0.3703</td>
#       <td id="T_e9371_row0_col3" class="data row0 col3" >0.5674</td>
#       <td id="T_e9371_row0_col4" class="data row0 col4" >0.9979</td>
#       <td id="T_e9371_row0_col5" class="data row0 col5" >0.1026</td>
#       <td id="T_e9371_row0_col6" class="data row0 col6" >0.0113</td>
#       <td id="T_e9371_row0_col7" class="data row0 col7" >4.2810</td>
#     </tr>
#     <tr>
#       <th id="T_e9371_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_e9371_row1_col0" class="data row1 col0" >Ridge Regression</td>
#       <td id="T_e9371_row1_col1" class="data row1 col1" >0.0648</td>
#       <td id="T_e9371_row1_col2" class="data row1 col2" >0.3703</td>
#       <td id="T_e9371_row1_col3" class="data row1 col3" >0.5674</td>
#       <td id="T_e9371_row1_col4" class="data row1 col4" >0.9979</td>
#       <td id="T_e9371_row1_col5" class="data row1 col5" >0.1026</td>
#       <td id="T_e9371_row1_col6" class="data row1 col6" >0.0113</td>
#       <td id="T_e9371_row1_col7" class="data row1 col7" >1.1270</td>
#     </tr>
#     <tr>
#       <th id="T_e9371_level0_row2" class="row_heading level0 row2" >lar</th>
#       <td id="T_e9371_row2_col0" class="data row2 col0" >Least Angle Regression</td>
#       <td id="T_e9371_row2_col1" class="data row2 col1" >0.0648</td>
#       <td id="T_e9371_row2_col2" class="data row2 col2" >0.3703</td>
#       <td id="T_e9371_row2_col3" class="data row2 col3" >0.5674</td>
#       <td id="T_e9371_row2_col4" class="data row2 col4" >0.9979</td>
#       <td id="T_e9371_row2_col5" class="data row2 col5" >0.1026</td>
#       <td id="T_e9371_row2_col6" class="data row2 col6" >0.0113</td>
#       <td id="T_e9371_row2_col7" class="data row2 col7" >1.1240</td>
#     </tr>
#     <tr>
#       <th id="T_e9371_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_e9371_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_e9371_row3_col1" class="data row3 col1" >0.0648</td>
#       <td id="T_e9371_row3_col2" class="data row3 col2" >0.3703</td>
#       <td id="T_e9371_row3_col3" class="data row3 col3" >0.5674</td>
#       <td id="T_e9371_row3_col4" class="data row3 col4" >0.9979</td>
#       <td id="T_e9371_row3_col5" class="data row3 col5" >0.1026</td>
#       <td id="T_e9371_row3_col6" class="data row3 col6" >0.0113</td>
#       <td id="T_e9371_row3_col7" class="data row3 col7" >1.1830</td>
#     </tr>
#     <tr>
#       <th id="T_e9371_level0_row4" class="row_heading level0 row4" >par</th>
#       <td id="T_e9371_row4_col0" class="data row4 col0" >Passive Aggressive Regressor</td>
#       <td id="T_e9371_row4_col1" class="data row4 col1" >0.1395</td>
#       <td id="T_e9371_row4_col2" class="data row4 col2" >0.4116</td>
#       <td id="T_e9371_row4_col3" class="data row4 col3" >0.6150</td>
#       <td id="T_e9371_row4_col4" class="data row4 col4" >0.9977</td>
#       <td id="T_e9371_row4_col5" class="data row4 col5" >0.1025</td>
#       <td id="T_e9371_row4_col6" class="data row4 col6" >0.0368</td>
#       <td id="T_e9371_row4_col7" class="data row4 col7" >1.4120</td>
#     </tr>
#     <tr>
#       <th id="T_e9371_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_e9371_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_e9371_row5_col1" class="data row5 col1" >0.1684</td>
#       <td id="T_e9371_row5_col2" class="data row5 col2" >0.4580</td>
#       <td id="T_e9371_row5_col3" class="data row5 col3" >0.6291</td>
#       <td id="T_e9371_row5_col4" class="data row5 col4" >0.9975</td>
#       <td id="T_e9371_row5_col5" class="data row5 col5" >0.1070</td>
#       <td id="T_e9371_row5_col6" class="data row5 col6" >0.0457</td>
#       <td id="T_e9371_row5_col7" class="data row5 col7" >1.5650</td>
#     </tr>
#     <tr>
#       <th id="T_e9371_level0_row6" class="row_heading level0 row6" >lasso</th>
#       <td id="T_e9371_row6_col0" class="data row6 col0" >Lasso Regression</td>
#       <td id="T_e9371_row6_col1" class="data row6 col1" >0.1337</td>
#       <td id="
# Processing:   0%|          | 0/77 [00:00<?, ?it/s]

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1586f_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1586f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1586f_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_1586f_row0_col1" class="data row0 col1" >0.0957</td>
#       <td id="T_1586f_row0_col2" class="data row0 col2" >20.5970</td>
#       <td id="T_1586f_row0_col3" class="data row0 col3" >4.5384</td>
#       <td id="T_1586f_row0_col4" class="data row0 col4" >0.9082</td>
#       <td id="T_1586f_row0_col5" class="data row0 col5" >0.1011</td>
#       <td id="T_1586f_row0_col6" class="data row0 col6" >0.0114</td>
#     </tr>
#   </tbody>
# </table>
#         Semana  Ruta_SAK  Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  \
# 81617      3.0    1202.0           10.0  45.000000              0.0
# 81618      8.0    2848.0            1.0   7.410000              0.0
# 81619      9.0    1411.0            2.0  21.379999              3.0
# 81620      5.0    1256.0            1.0  10.690000              0.0
# 81621      6.0    1229.0            1.0  16.350000              0.0
# ...        ...       ...            ...        ...              ...
# 116591     6.0    3922.0            4.0  12.080000              0.0
# 116592     6.0    1285.0           10.0  30.200001              0.0
# 116593     4.0    2855.0            1.0   6.760000              0.0
# 116594     6.0    1014.0            4.0  60.040001              0.0
# 116595     8.0    1405.0            7.0  68.809998              0.0
#
#         Dev_proxima  NombreCliente       Town      State  NombreProducto  \
# 81617          0.00       8.987772  13.374552  13.148304       25.208114
# 81618          0.00       8.516564   6.756477   4.344300        5.848657
# 81619         32.07       8.267974   6.684300   6.860654        2.893221
# 81620          0.00       5.933333   5.847222  10.487973        2.893221
# 81621          0.00       6.650000   6.471429   7.380174        2.772417
# ...             ...            ...        ...        ...             ...
# 116591         0.00       8.987772  13.320084  10.487973       11.530955
# 116592         0.00       8.987772  14.310705  13.148304       11.530955
# 116593         0.00      12.500000  12.156983  11.797231        2.608918
# 116594         0.00       8.987772   6.448276  10.487973        3.225932
# 116595         0.00       8.526316   6.684300   6.860654        2.923218
#
#         Demanda_uni_equil  prediction_label
# 81617                  10         10.007628
# 81618                   1          1.002853
# 81619                   0          0.845594
# 81620                   1          0.985202
# 81621                   1          0.984243
# ...                   ...               ...
# 116591                  4          4.024279
# 116592                 10          9.997659
# 116593                  1          1.008004
# 116594                  4          3.957673
# 116595                  7          6.953637
#
# [34979 rows x 12 columns]

# %%
best
# Out:
# LinearRegression(n_jobs=-1)
