# %%
import pandas as pd

# %%
C
df2 = pd.read_csv('./Dataset/1.cliente_tabla.csv')
df3 = pd.read_csv('./Dataset/2.producto_tabla.csv')
df4 = pd.read_csv('./Dataset/3.town_state.csv')
df5 = pd.read_csv('./Dataset/4.df_adress_coord.csv')
df_main = pd.read_csv("Dataset_dashboard/main.csv")

# %%
df_target = pd.read_csv("./Dataset_dashboard/target.csv")

# %%
df_main['Predicted'] = df_target

# %%
df_main
# Out:
#         Week  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 0          5        1936         1      1158     1575677         2425
# 1          8        1936         1      1158      841050         2425
# 2          6        1936         1      1158     3422113         2425
# 3          7        1936         1      1158     1570783         2425
# 4          9        1936         1      1158     2296923         2425
# ...      ...         ...       ...       ...         ...          ...
# 964343     6        1167         2      7031     1404831        37000
# 964344     5        1524         2      9325     1665774        37000
# 964345     8        1167         2      8096      928089        47910
# 964346     7        4035         2      1810      636789        45223
# 964347     6        1524         2      6096       27549        36886
#
#         SalesUnitWeek  SalesPesosWeek  ReturnsUnitNextWeek  \
# 0                  60          270.00                    0
# ...

# %%
df1.head()
# Out:
#    Week  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 0     5        1936         1      1158     1575677         2425
# 1     8        1936         1      1158      841050         2425
# 2     6        1936         1      1158     3422113         2425
# 3     7        1936         1      1158     1570783         2425
# 4     9        1936         1      1158     2296923         2425
#
#    SalesUnitWeek  SalesPesosWeek  ReturnsUnitNextWeek  RetrunsPesosNextWeek  \
# 0             60           270.0                    0                   0.0
# 1             20            90.0                    0                   0.0
# 2             10            45.0                    0                   0.0
# 3             25           112.5                    0                   0.0
# 4             23           103.5                    0                   0.0
#
#    ...   Latitude  Longitude                NombreProducto short_name brand  \
# ...

# %%
df1.columns
# Out:
# Index(['Week', 'Agencia_ID', 'Canal_ID', 'Ruta_SAK', 'Cliente_ID',
#        'Producto_ID', 'SalesUnitWeek', 'SalesPesosWeek', 'ReturnsUnitNextWeek',
#        'RetrunsPesosNextWeek', 'AjustedDemand', 'Town', 'State', 'Address',
#        'typeClient', 'Latitude', 'Longitude', 'NombreProducto', 'short_name',
#        'brand', 'weight', 'pieces', 'Ruta_SAK_counts', 'ReturnUnitMissing',
#        'ReturnPesosMissing'],
#       dtype='object')

# %%
df2.head()
# Out:
#    Cliente_ID                            NombreCliente
# 0           0                               SIN NOMBRE
# 1           1                         OXXO XINANTECATL
# 2           2                               SIN NOMBRE
# 3           3                                EL MORENO
# 4           4  SDN SER  DE ALIM  CUERPO SA CIA  DE INT

# %%
df_client = df2.merge(df1[["Cliente_ID", "typeClient"]], on='Cliente_ID', how='inner')

# %%
df_produto = df3.merge(df1[["Producto_ID", "short_name", 'pieces', 'brand', 'weight']], on='Producto_ID', how='inner')

# %%
df_state = df4.merge(df1[["Agencia_ID", 'Latitude', 'Longitude']], on='Agencia_ID', how='inner')

# %%
df1.columns
# Out:
# Index(['Week', 'Agencia_ID', 'Canal_ID', 'Ruta_SAK', 'Cliente_ID',
#        'Producto_ID', 'SalesUnitWeek', 'SalesPesosWeek', 'ReturnsUnitNextWeek',
#        'RetrunsPesosNextWeek', 'AjustedDemand', 'Town', 'State', 'Address',
#        'typeClient', 'Latitude', 'Longitude', 'NombreProducto', 'short_name',
#        'brand', 'weight', 'pieces', 'Ruta_SAK_counts', 'ReturnUnitMissing',
#        'ReturnPesosMissing'],
#       dtype='object')

# %%
df_main = df1[['Week', 'Agencia_ID', 'Canal_ID', 'Ruta_SAK', 'Cliente_ID',
       'Producto_ID', 'SalesUnitWeek', 'SalesPesosWeek', 'ReturnsUnitNextWeek',
       'RetrunsPesosNextWeek', 'AjustedDemand', 'Ruta_SAK_counts', 'ReturnUnitMissing',
       'ReturnPesosMissing']]

# %%
df_main
# Out:
#         Week  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 0          5        1936         1      1158     1575677         2425
# 1          8        1936         1      1158      841050         2425
# 2          6        1936         1      1158     3422113         2425
# 3          7        1936         1      1158     1570783         2425
# 4          9        1936         1      1158     2296923         2425
# ...      ...         ...       ...       ...         ...          ...
# 964343     6        1167         2      7031     1404831        37000
# 964344     5        1524         2      9325     1665774        37000
# 964345     8        1167         2      8096      928089        47910
# 964346     7        4035         2      1810      636789        45223
# 964347     6        1524         2      6096       27549        36886
#
#         SalesUnitWeek  SalesPesosWeek  ReturnsUnitNextWeek  \
# 0                  60          270.00                    0
# ...

# %%
df_client.to_csv('./Dataset_dashboard/client.csv', index = False)
df_produto.to_csv('./Dataset_dashboard/product.csv', index=False)
df_state.to_csv('./Dataset_dashboard/town_state.csv', index=False)
df_main.to_csv('./Dataset_dashboard/main.csv', index = False)

# %%
df_main.to_csv('./Dataset_dashboard/main.csv', index = False)
